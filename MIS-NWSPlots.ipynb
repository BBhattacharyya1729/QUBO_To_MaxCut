# %%
import pickle as pkl
from QAOAUtils import *
from tqdm import tqdm
from tqdm.contrib import itertools
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from matplotlib.markers import MarkerStyle
# Out:
# (CVXPY) Aug 17 10:10:29 AM: Encountered unexpected exception importing solver OSQP:
# ImportError('DLL load failed while importing qdldl: The specified module could not be found.')

# %%
DATA = pkl.load( open ("MIS-NWSFullTest.p", "rb") )

# %%
depth_DATA= pkl.load( open ("TSP_MISDepth0Test.p", "rb") )
idx_list = np.linspace(50,950,10,dtype='int')
M_list= [depth_DATA[2][i][-1] for i in idx_list]
idx_dict = {'MIS-NWS':[0,10]}

# %%
get_depth_cost_comp("MIS-NWS",idx_dict,DATA,M_list, path=r'Figures\MIS-NWS\Full_Cost_Comparison')

# %%
get_depth_prob_comp("MIS-NWS",idx_dict,DATA,M_list, path=r'Figures\MIS-NWS\Full_Prob_Comparison')
