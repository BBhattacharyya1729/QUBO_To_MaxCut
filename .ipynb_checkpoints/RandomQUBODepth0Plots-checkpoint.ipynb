# %%
import pickle as pkl
from QAOAUtils import *
from tqdm import tqdm
from tqdm.contrib import itertools
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from matplotlib.markers import MarkerStyle
from matplotlib.gridspec import GridSpec
# Out:
# (CVXPY) Aug 10 05:23:47 PM: Encountered unexpected exception importing solver OSQP:
# ImportError('DLL load failed while importing qdldl: The specified module could not be found.')

# %%
DATA= pkl.load( open ("RandomQUBODepth0Test.p", "rb") )

# %%
p_data = {'Continous':DATA[0:4],'Discrete':DATA[4:8]}
ws_list = ['BM2','BM3','GW2','GW3']

# %%
max_cost_hist("Discrete",p_data)

# %%
max_cost_hist("Continous",p_data)

# %%
max_prob_hist("Discrete",p_data)

# %%
max_prob_hist("Continous",p_data)

# %%
cost_scatter("Discrete",p_data)

# %%
cost_scatter("Continous",p_data)

# %%
prob_boxplot("Discrete", p_data)

# %%
prob_boxplot("Continous", p_data)

# %%
final_boxplot("Discrete", p_data)

# %%
final_boxplot("Continous", p_data)
