# %%
import pickle as pkl
from QAOAUtils import *
from tqdm import tqdm
from tqdm.contrib import itertools
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from matplotlib.markers import MarkerStyle
from matplotlib.gridspec import GridSpec
# Out:
# (CVXPY) Dec 12 12:04:00 AM: Encountered unexpected exception importing solver OSQP:
# ImportError('DLL load failed while importing qdldl: The specified module could not be found.')

# %%
DATA = pkl.load( open ("MISNWSFullTest.p", "rb") )
PSC_DATA = pkl.load( open ("PSCMISNWSFullTest.p", "rb") )
depth_DATA= pkl.load( open ("TSPMISDepth0Test.p", "rb") )
PSC_DATA50 = pkl.load( open ("PSCMISNWSFullTest50.p", "rb") )
with open("DistancesMIS-NWS.p", "rb") as file:
    results = pkl.load(file)
VDISTANCE50 = results["VDISTANCE50"]
DISTANCE50 = results["DISTANCE50"]
VDISTANCE10 = results["VDISTANCE10"]
DISTANCE10 = results["DISTANCE10"]
PSCDISTANCE10 = results["PSCDISTANCE10"]
PSCDISTANCE50 = results["PSCDISTANCE50"]
PSCVDISTANCE10 = results["PSCVDISTANCE10"]
PSCVDISTANCE50 = results["PSCVDISTANCE50"]

# %%
idx_list = np.linspace(50,950,10,dtype='int')
M_list= [depth_DATA[10][i][-1] for i in idx_list]
A_list = [depth_DATA[11][i] for i in idx_list]
idx_dict = {'MIS-NWS':[0,10]}
p_data = {'MIS-NWS':depth_DATA[8:12]}
ws_list = ['BM2','BM3','GW2','GW3']

# %%
max_cost_hist("MIS-NWS",p_data, path=r'Figures\MIS-NWS\Max_Cost_Hist')

# %%
max_prob_hist("MIS-NWS",p_data, path=r'Figures\MIS-NWS\Max_Prob_Hist')

# %%
cost_scatter("MIS-NWS",p_data, path=r'Figures\MIS-NWS\Cost_Scatter')

# %%
prob_boxplot("MIS-NWS", p_data, path=r'Figures\MIS-NWS\Prob_BoxPlot')

# %%
final_boxplot("MIS-NWS", p_data, path=r'Figures\MIS-NWS\Comparison_Boxplot')

# %%
plot_distance("MIS-NWS", DISTANCE10, DISTANCE50, path=r'Figures\MIS-NWS\Hypercube')

# %%
get_depth_combined('MIS-NWS', idx_dict, PSC_DATA, DATA, PSC_DATA50, M_list, A_list, path=r'Figures\MIS-NWS\Full_Comparison', p_max=5, std=.25)

# %%
get_depth_combined_gw2('MIS-NWS', idx_dict, PSC_DATA, DATA, PSC_DATA50, M_list, A_list, path=r'Figures\MIS-NWS\Full_Comparison_gw2', p_max=5, std=.25)

# %%
depth_points_gw2 = calculate_depth_points_gw2("MIS-NWS", idx_dict, PSC_DATA, DATA, PSC_DATA50, M_list, A_list)
plot_numbers("MIS-NWS", depth_points_gw2)
# Out:
# -------------------------------------------------------
#                      MIS-NWS
# Warmstart Values                    p          a
# -------------------------------------------------------
# None                                0.0516     0.8818
# Warmstart No Rotation               0.4063     0.9623
# Warmstart First Rotation            0.475      0.9697
# Warmstart Last Rotation             0.5402     0.9729
# QUBO Relaxed (10 Initializations)   0.4172     0.9576
# QUBO Relaxed (50 Initializations)   0.6122     0.9767
# -------------------------------------------------------
# Greatest-Least, + standard deviatons
#
# Warmstarts for p (greatest to least):
# 1. QUBO Relaxed (50 Initializations): Warmstart Last Rotation Warmstart First Rotation QUBO Relaxed (10 Initializations)
# 2. Warmstart Last Rotation: QUBO Relaxed (50 Initializations) Warmstart First Rotation QUBO Relaxed (10 Initializations) Warmstart No Rotation
# 3. Warmstart First Rotation: QUBO Relaxed (50 Initializations) Warmstart Last Rotation QUBO Relaxed (10 Initializations) Warmstart No Rotation
# 4. QUBO Relaxed (10 Initializations): QUBO Relaxed (50 Initializations) Warmstart Last Rotation Warmstart First Rotation Warmstart No Rotation
# 5. Warmstart No Rotation: Warmstart Last Rotation Warmstart First Rotation QUBO Relaxed (10 Initializations)
# 6. None: 0
#
# Warmstarts for a (greatest to least):
# 1. QUBO Relaxed (50 Initializations): Warmstart Last Rotation Warmstart First Rotation Warmstart No Rotation
# 2. Warmstart Last Rotation: QUBO Relaxed (50 Initializations) Warmstart First Rotation Warmstart No Rotation QUBO Relaxed (10 Initializations)
# 3. Warmstart First Rotation: QUBO Relaxed (50 Initializations) Warmstart Last Rotation Warmstart No Rotation QUBO Relaxed (10 Initializations)
# 4. Warmstart No Rotation: QUBO Relaxed (50 Initializations) Warmstart Last Rotation Warmstart First Rotation QUBO Relaxed (10 Initializations)
# 5. QUBO Relaxed (10 Initializations): Warmstart Last Rotation Warmstart First Rotation Warmstart No Rotation
# 6. None: 0
