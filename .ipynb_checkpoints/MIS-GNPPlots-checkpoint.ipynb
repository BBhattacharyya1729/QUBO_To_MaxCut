# %%
import pickle as pkl
from QAOAUtils import *
from tqdm import tqdm
from tqdm.contrib import itertools
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from matplotlib.markers import MarkerStyle
# Out:
# (CVXPY) Aug 16 05:45:22 PM: Encountered unexpected exception importing solver OSQP:
# ImportError('DLL load failed while importing qdldl: The specified module could not be found.')

# %%
DATA = pkl.load( open ("MIS-GNPFullTest.p", "rb") )

# %%
depth_DATA= pkl.load( open ("TSP_MISDepth0Test.p", "rb") )
idx_list = np.linspace(50,950,10,dtype='int')
M_list= [depth_DATA[2][i][-1] for i in idx_list]
idx_dict = {'MIS-GNP':[0,10]}

# %%
get_depth_cost_comp("MIS-GNP",idx_dict,DATA,M_list, path=r'Figures\MIS-GNP\Full_Cost_Comparison')

# %%
get_depth_prob_comp("MIS-GNP",idx_dict,DATA,M_list, path=r'Figures\MIS-GNP\Full_Prob_Comparison')
